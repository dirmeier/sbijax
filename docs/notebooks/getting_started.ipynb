# %% [markdown]
# # Getting started
#
# `Sbijax` is a Python package for neural simulation-based inference and approximate Bayesian computation. Here we demonstrate its core functionality using a simple Gaussian model.

# %%
import jax
import sbijax

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def plot_posterior_hist(samples, key="theta", var_names=["mean[0]", "mean[1]", "variance"], bins=40):
  theta = samples[key].reshape(-1, samples[key].shape[-1])
  d = theta.shape[-1]
  fig, axes = plt.subplots(1, d, figsize=(3 * d, 3))
  axes = [axes] if d == 1 else list(axes)
  for i, (var_name, ax) in enumerate(zip(var_names, axes)):
    ax.hist(theta[:, i], bins=bins)
    ax.set_title(var_name)
  fig.tight_layout()
  return fig

# %% [markdown]
# ## Model definition
#
# To do approximate inference using `sbijax`, a user first has to define a prior model and a simulator function which can be used to generate synthetic data. We use a Normal-Inverse-Gamma model since it is conjugate such that we compare it to the analytical posterior:
#
# \begin{align}
# \sigma^2 &\sim \text{InvGamma}(a_0, b_0)\\
# \mu \mid \sigma^2 &\sim \mathcal{N}_2\left(0, \frac{\sigma^2}{\kappa_0} I\right)\\
# y \mid \mu, \sigma^2 & \sim \mathcal{N}_2(\mu, \sigma^2 I)
# \end{align}
#
# Using TensorFlow Probability, the prior model and simulator are implemented like this:

# %%
from jax import numpy as jnp, random as jr
from tensorflow_probability.substrates.jax import distributions as tfd


a0, b0, kappa0 = 3.0, 2.0, 1.0


def prior_fn():
  prior = tfd.JointDistributionNamed(
    dict(
      variance=tfd.InverseGamma(
        concentration=a0 * jnp.ones(1), scale=b0 * jnp.ones(1)
      ),
      mean=lambda variance: tfd.Normal(jnp.zeros(2), jnp.sqrt(variance / kappa0)),
    ),
    batch_ndims=0,
  )
  return prior


def simulator_fn(seed: jr.key, theta: dict[str, jax.Array]):
  p = tfd.Normal(jnp.zeros_like(theta["mean"]), jnp.sqrt(theta["variance"]))
  y = theta["mean"] + p.sample(seed=seed)
  return y

# %% [markdown]
# ### What exactly a prior and a simulator need to look like
#
# A **prior** needs a `.sample(seed=rng_key)` method returning a pytree, a batched form `.sample(seed=rng_key, sample_shape=(n,))`, and a `.log_prob(theta)` method that accepts that same pytree structure. A pytree here just means a (possibly nested) dict of arrays, e.g. what `prior_fn().sample(...)` returns above:
#
# ```python
# {"variance": Array([0.76]), "mean": Array([1.11, -0.58])}
# ```
#
# Nothing in `sbijax` checks that the prior is literally a `tfd` distribution — only `.sample` and `.log_prob` are ever called on it — but every example here uses one, since `tfd.JointDistributionNamed` gives you both for free (including the `mean`-given-`variance` coupling above, via a plain lambda).
#
# A **simulator** must accept a `seed` and a `theta` argument — and, because ABC methods (`sabc`/`smcabc`) call it by keyword internally, those two names specifically (or `**kwargs`), not e.g. `rng_key`. `simulate` and `run_sequential` always call it with a **batched** `theta` (a leading axis of size `n`), so the function body has to handle a batch of parameter draws, not a single one — as `simulator_fn` does above by broadcasting over `theta["mean"]`'s leading axis.

# %% [markdown]
# ## Algorithm definition
#
# Having defined a model of interest, i.e., the prior and simulator functions, we construct an inferential method. Here, we use flow matching posterior estimation (FMPE) which is an algorithm that directly aims to learn an approximation to the posterior distribution (without intermediate steps like neural likelihood or neural likelihood-ratio estimation methods).

# %% [markdown]
# FMPE requires a continuous normalizing flow as a neural network model. We can construct it using the functionality provided by `sbijax`.

# %%
from sbijax.nn import make_cnf

n_dim_theta = 3
n_layers, hidden_size = 2, 128
neural_network = make_cnf(n_dim_theta, n_layers, hidden_size)

# %% [markdown]
# The neural network model in FMPE targets the posterior distribution and hence needs to target a space with its dimensionaliy. One can either find the dimensionality by inspecting the prior model (above, two for the mean and one for the variance), or use one of JAX internal methods, ravel_pytree, for this:

# %%
prior_draw = prior_fn().sample(seed=jr.key(1))
prior_draw
# Out:
# {'variance': Array([0.75851035], dtype=float32),
#  'mean': Array([ 1.1123704 , -0.57603586], dtype=float32)}

# %%
len(jax.flatten_util.ravel_pytree(prior_draw)[0])
# Out:
# 3

# %% [markdown]
# The result matches `n_dim_theta` above: `mean` contributes 2 entries and `variance` contributes 1 (it is a single value shared isotropically across both components of `y`, not one per dimension), for 3 flattened entries in total.

# %% [markdown]
# We can then construct the method itself. Every method is a factory function that returns a tuple of pure functions (a tuple named `ObjectiveFns`). It takes as arguments only neural network.

# %%
from sbijax import fmpe

model = fmpe(neural_network)

# %% [markdown]
# In the case of FMPE, `ObjectiveFns` contains set of training functions contained in another tuple called `TrainFns` and a sampling function `sample_fn`. As mentioned, all functions follow the common `JAX` and `dm-haiku` idiom, and are pure with no side-effects.

# %%
model
# Out:
# ObjectiveFns(train=TrainFns(init_fn=<function fmpe.<locals>.init_fn at 0x11ce3f880>, step_fn=<function fmpe.<locals>.step_fn at 0x11ce3f9c0>, eval_fn=<function fmpe.<locals>.eval_fn at 0x11ce3f4c0>), sample_fn=<function fmpe.<locals>.sample_fn at 0x11ce3f740>, extra=None)

# %% [markdown]
# We will use both of these later.

# %% [markdown]
# ## Training
#
# Inference is then as easy as simulating some data, fitting the data to the model, a sampling from the approximate posterior. The data set is a dictionary of dictionaries (a PyTree in JAX lingo). It contains samples for the simulator function, called `y`, and parameter samples from the prior model, called `theta`.

# %%
from sbijax import simulate

prior = prior_fn()
data = simulate(
  jr.key(1),
  prior,
  simulator_fn,
  n=10_000,
)
data
# Out:
# {'y': Array([[ 0.03531116,  0.4839089 ],
#         [-1.4265001 , -0.6979415 ],
#         [ 2.0866137 , -2.7471685 ],
#         ...,
#         [ 0.8941377 , -0.06710297],
#         [ 3.7776628 , -3.127647  ],
#         [ 0.2032855 ,  1.8556728 ]], dtype=float32),
#  'theta': {'variance': Array([[0.3680383 ],
#          [0.6824566 ],
#          [1.7586074 ],
#          ...,
#          [0.6962748 ],
#          [0.72820413],
#          [1.9503669 ]], dtype=float32),
#   'mean': Array([[ 0.18328808,  0.4093683 ],
#          [-0.7959225 ,  0.07125441],
#          [ 0.51778406, -2.9676378 ],
#          ...,
#          [ 1.1392292 ,  0.5259131 ],
#          [ 2.3503807 , -1.6299648 ],
#          [-0.23107295,  0.9043303 ]], dtype=float32)}}

# %% [markdown]
# `data` mirrors the prior's own pytree structure, batched over a leading axis of size `n`: `data["theta"]` has the same `mean`/`variance` keys as a single prior draw, and `data["y"]` holds the corresponding simulated observations.

# %% [markdown]
# We then fit the model using the typical flow matching loss.

# %%
from sbijax import train


params, info = train(
  jr.key(2), model, data, n_iter=100, n_early_stopping_patience=20
)
# Out:
#  45%|███████████████████████████████████████████████████████████████▉                                                                              | 45/100 [00:27<00:33,  1.62it/s]

# %% [markdown]
# Let's have a look if the training worked. Both curves (training and validation loss) should decrease and flatten out; a validation loss that turns upward again would indicate overfitting.

# %%
plt.plot(info.losses[1:, 0], label="train")
plt.plot(info.losses[1:, 1], label="validation")
plt.xlabel("step")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Inference

# %% [markdown]
# Finally, we sample from the posterior distribution for a specific observation $y_{\text{obs}}$.

# %%
from sbijax import sample


y_obs = jnp.array([-1.0, 1.0])
samples, _ = sample(
  jr.key(3), model, params, y_obs, prior=prior, n_samples=1_000
)

# %% [markdown]
# Because the prior is Normal-Inverse-Gamma and the likelihood is Gaussian, this model is conjugate: the posterior given `y_obs` is again Normal-Inverse-Gamma, and can be sampled directly, without MCMC or FMPE. For a single 2-D observation $y$ and prior hyperparameters $(a_0, b_0, \kappa_0, \mu_0=0)$, the update is
#
# \begin{align}
# \kappa_1 = \kappa_0 + 1, \quad
# \mu_1 = \frac{\kappa_0 \mu_0 + y}{\kappa_0 + 1}, \quad
# a_1 = a_0 + 1, \quad
# b_1 = b_0 + \frac{\kappa_0}{2(\kappa_0+1)}\lVert y - \mu_0 \rVert^2
# \end{align}
#
# with $\sigma^2 \mid y \sim \text{InvGamma}(a_1, b_1)$ and $\mu \mid \sigma^2, y \sim \mathcal{N}_2(\mu_1, \sigma^2/\kappa_1 \, I)$. We compute this directly below.

# %%
kappa1 = kappa0 + 1
mu1 = (kappa0 * jnp.zeros(2) + y_obs) / kappa1
a1 = a0 + 1
b1 = b0 + 0.5 * (kappa0 / kappa1) * jnp.sum(y_obs**2)

variance_dist = tfd.InverseGamma(concentration=a1, scale=b1)
mean_dist = tfd.StudentT(df=2 * a1, loc=mu1, scale=jnp.sqrt(b1 / (a1 * kappa1)))
exact_dists = [mean_dist[0], mean_dist[1], variance_dist]

# %% [markdown]
# Now let's visualize the analytical densities against the FMPE-inferred ones.

# %%
draws = [
  samples["mean"][0, :, 0],
  samples["mean"][0, :, 1],
  samples["variance"][0, :, 0],
]
fig, axes = plt.subplots(1, 3, figsize=(9, 3))
for ax, name, dist, x in zip(
  axes, ["mean[0]", "mean[1]", "variance"], exact_dists, draws
):
  ax.hist(x, bins=30, density=True, alpha=0.5, label="FMPE")
  grid = jnp.linspace(x.min(), x.max(), 200)
  ax.plot(grid, dist.prob(grid), color="black", label="exact")
  ax.set_title(name)
axes[0].legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# Histograms are FMPE's samples; the black curve is the exact marginal density (a Student-t for each `mean` component, an Inverse-Gamma for `variance`).

# %% [markdown]
# ## Session info

# %%
import session_info

session_info.show(html=False)
# Out:
# -----
# haiku                       0.0.17
# jax                         0.11.1
# jaxlib                      0.11.1
# matplotlib                  3.10.8
# sbijax                      0.4.0
# session_info                v1.0.1
# tensorflow_probability      0.26.0-dev20260318
# -----
# IPython             9.11.0
# jupyter_client      8.8.0
# jupyter_core        5.9.1
# jupyterlab          4.5.6
# notebook            7.5.5
# -----
# Python 3.12.10 (main, May 30 2025, 05:53:56) [Clang 20.1.4 ]
# macOS-26.2-arm64-arm-64bit
# -----
# Session information updated at 2026-09-12 22:07
